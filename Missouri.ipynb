# %%
# %matplotlib inline
import geopandas as gpd
import pandas as pd

# %%
pop = gpd.read_file('cb_2018_29_tract_500k.shp')

# %%
pop.shape
# Out:
# (1393, 10)

# %%
pop.head()
# Out:
#   STATEFP COUNTYFP TRACTCE              AFFGEOID        GEOID    NAME LSAD  \
# 0      29      047  021403  1400000US29047021403  29047021403  214.03   CT
# 1      29      051  010300  1400000US29051010300  29051010300     103   CT
# 2      29      063  080100  1400000US29063080100  29063080100     801   CT
# 3      29      071  800500  1400000US29071800500  29071800500    8005   CT
# 4      29      077  000100  1400000US29077000100  29077000100       1   CT
#
#        ALAND   AWATER                                           geometry
# 0    2870160        0  POLYGON ((-94.44325 39.24450, -94.43949 39.244...
# 1    9809676   894852  POLYGON ((-92.15916 38.56560, -92.15844 38.565...
# 2  541711484  5945714  POLYGON ((-94.46237 40.00440, -94.46233 40.010...
# 3  513660844   845774  POLYGON ((-91.36753 38.20802, -91.36748 38.209...
# 4    1074007        0  POLYGON ((-93.29872 37.20855, -93.29657 37.208...

# %%
pop.plot()
